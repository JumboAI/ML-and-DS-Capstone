# %%
import pandas as pd
import numpy as np
from Univariate import Univariate
# Out:
# D:\APPS\Anaconda\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
dataset=pd.read_csv('merged_data.csv')

# %%
dataset
# Out:
#        Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0        20.750000          Low Fat         0.007565         Snack Foods
# 1         8.300000              reg         0.038428               Dairy
# 2        14.600000          Low Fat         0.099575              Others
# 3         7.315000          Low Fat         0.015388         Snack Foods
# 4        12.792854          Regular         0.118599               Dairy
# ...            ...              ...              ...                 ...
# 14199     6.865000          Low Fat         0.056783         Snack Foods
# 14200     8.380000          Regular         0.046982        Baking Goods
# 14201    10.600000          Low Fat         0.035186  Health and Hygiene
# 14202     7.210000          Regular         0.145221         Snack Foods
# 14203    14.800000          Low Fat         0.044878         Soft Drinks
#
#        Item_MRP Outlet_Size Outlet_Location_Type        Outlet_Type  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Weight           14204 non-null  float64
#  1   Item_Fat_Content      14204 non-null  object
#  2   Item_Visibility       14204 non-null  float64
#  3   Item_Type             14204 non-null  object
#  4   Item_MRP              14204 non-null  float64
#  5   Outlet_Size           14204 non-null  object
#  6   Outlet_Location_Type  14204 non-null  object
#  7   Outlet_Type           14204 non-null  object
#  8   Item_Outlet_Sales     8523 non-null   float64
# dtypes: float64(4), object(5)
# memory usage: 998.8+ KB

# %%
dataset['Item_Outlet_Sales'].isnull().sum()
# Out:
# 5681

# %%
dataset['Item_Outlet_Sales'].dtypes
# Out:
# dtype('float64')

# %%
dataset['Item_Outlet_Sales'].fillna(dataset['Item_Outlet_Sales'].mean(),inplace=True)
# Out:
# C:\Users\Rajesh\AppData\Local\Temp\ipykernel_12084\565379692.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Item_Outlet_Sales'].fillna(dataset['Item_Outlet_Sales'].mean(),inplace=True)

# %%
#check all missing data filled
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Weight           14204 non-null  float64
#  1   Item_Fat_Content      14204 non-null  object
#  2   Item_Visibility       14204 non-null  float64
#  3   Item_Type             14204 non-null  object
#  4   Item_MRP              14204 non-null  float64
#  5   Outlet_Size           14204 non-null  object
#  6   Outlet_Location_Type  14204 non-null  object
#  7   Outlet_Type           14204 non-null  object
#  8   Item_Outlet_Sales     14204 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 998.8+ KB

# %%
dataset
# Out:
#        Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0        20.750000          Low Fat         0.007565         Snack Foods
# 1         8.300000              reg         0.038428               Dairy
# 2        14.600000          Low Fat         0.099575              Others
# 3         7.315000          Low Fat         0.015388         Snack Foods
# 4        12.792854          Regular         0.118599               Dairy
# ...            ...              ...              ...                 ...
# 14199     6.865000          Low Fat         0.056783         Snack Foods
# 14200     8.380000          Regular         0.046982        Baking Goods
# 14201    10.600000          Low Fat         0.035186  Health and Hygiene
# 14202     7.210000          Regular         0.145221         Snack Foods
# 14203    14.800000          Low Fat         0.044878         Soft Drinks
#
#        Item_MRP Outlet_Size Outlet_Location_Type        Outlet_Type  \
# ...

# %%
#call  using functions to seperate the numerical and categrorical data.. working fine
quan,qual=Univariate.quanQual(dataset)
# Out:
# Item_Weight
# Item_Fat_Content
# Item_Visibility
# Item_Type
# Item_MRP
# Outlet_Size
# Outlet_Location_Type
# Outlet_Type
# Item_Outlet_Sales

# %%
qual
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
quan
# Out:
# ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales']

# %%
dataset.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Item_Outlet_Sales
# count  14204.000000     14204.000000  14204.000000       14204.000000
# mean      12.792854         0.065953    141.004977        2181.288914
# std        4.234226         0.051459     62.086938        1321.864430
# min        4.555000         0.000000     31.290000          33.290000
# 25%        9.300000         0.027036     94.012000        1468.089000
# 50%       12.792854         0.054021    142.247000        2181.288914
# 75%       16.000000         0.094037    185.855600        2181.288914
# max       21.350000         0.328391    266.888400       13086.964800

# %%
#interquartile - remove lesser and greater outlier

# %%
dash=pd.DataFrame(index=['Mean',"Median","Mode","Q1:25%","Q2:50%","Q3:75%",'99%',"Q4:100%",'IQR','1.5rule','Lesser','Greater','Min',"Max"],columns=quan)
for colum in quan:
    dash[colum]['Mean']=dataset[colum].mean()
    dash[colum]['Median']=dataset[colum].median()
    dash[colum]['Mode']=dataset[colum].mode()[0]
    dash[colum]['Q1:25%']=np.percentile (dataset[colum],25)
    dash[colum]['Q2:50%']=np.percentile (dataset[colum],50)
    dash[colum]['Q3:75%']=np.percentile (dataset[colum],75)
    dash[colum]['99%']=np.percentile (dataset[colum],99)
    dash[colum]['Q4:100%']=np.percentile (dataset[colum],100)
    dash[colum]['IQR']=dash[colum]['Q3:75%']-dash[colum]['Q1:25%']
    dash[colum]['1.5rule']=1.5*dash[colum]['IQR']
    dash[colum]['Lesser']=dash[colum]['Q1:25%']-dash[colum]['1.5rule']
    dash[colum]['Greater']=dash[colum]['Q3:75%']+dash[colum]['1.5rule']
    dash[colum]['Min']=dash[colum].min()
    dash[colum]['Max']=dash[colum].max()
# Out:
# C:\Users\Rajesh\AppData\Local\Temp\ipykernel_12084\1023735892.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dash[colum]['Mean']=dataset[colum].mean()
# ...

# %%
dash
# Out:
#         Item_Weight Item_Visibility    Item_MRP Item_Outlet_Sales
# Mean      12.792854        0.065953  141.004977       2181.288914
# Median    12.792854        0.054021     142.247       2181.288914
# Mode      12.792854             0.0    172.0422       2181.288914
# Q1:25%          9.3        0.027036      94.012          1468.089
# Q2:50%    12.792854        0.054021     142.247       2181.288914
# Q3:75%         16.0        0.094037    185.8556       2181.288914
# 99%           20.85        0.230385  262.759322        6830.70852
# Q4:100%       21.35        0.328391    266.8884        13086.9648
# IQR             6.7        0.067002     91.8436        713.199914
# 1.5rule       10.05        0.100502    137.7654        1069.79987
# Lesser        -0.75       -0.073467    -43.7534         398.28913
# Greater       26.05         0.19454     323.621       3251.088784
# Min           -0.75       -0.073467    -43.7534         398.28913
# ...

# %%
#Min value must be higher then Lesser
#dash["Item_Outlet_Sales"]['Max']>dash["Item_Outlet_Sales"]['Greater']

# %%
#dash["Item_Weight"]['Min']<dash["Item_Weight"]['Lesser']

# %%
lesser=[]
greater=[]
for colum in quan:
    if (dash[colum]["Min"]<dash[colum]["Lesser"]):
        lesser.append(colum)
    if (dash[colum]["Max"]>dash[colum]["Greater"]):
         greater.append(colum)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# ['Item_Visibility', 'Item_Outlet_Sales']

# %%
for colum in lesser:
    dataset[colum][dataset[colum]<dash[colum]["Lesser"]]=dash[colum]["Lesser"]
for columName in greater:
    dataset[colum][dataset[colum]>dash[colum]["Greater"]]=dash[colum]["Greater"]
# Out:
# C:\Users\Rajesh\AppData\Local\Temp\ipykernel_12084\738189014.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataset[colum][dataset[colum]>dash[colum]["Greater"]]=dash[colum]["Greater"]
# ...

# %%
dash
# Out:
#         Item_Weight Item_Visibility    Item_MRP Item_Outlet_Sales
# Mean      12.792854        0.065953  141.004977       2181.288914
# Median    12.792854        0.054021     142.247       2181.288914
# Mode      12.792854             0.0    172.0422       2181.288914
# Q1:25%          9.3        0.027036      94.012          1468.089
# Q2:50%    12.792854        0.054021     142.247       2181.288914
# Q3:75%         16.0        0.094037    185.8556       2181.288914
# 99%           20.85        0.230385  262.759322        6830.70852
# Q4:100%       21.35        0.328391    266.8884        13086.9648
# IQR             6.7        0.067002     91.8436        713.199914
# 1.5rule       10.05        0.100502    137.7654        1069.79987
# Lesser        -0.75       -0.073467    -43.7534         398.28913
# Greater       26.05         0.19454     323.621       3251.088784
# Min           -0.75       -0.073467    -43.7534         398.28913
# ...

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# ['Item_Visibility', 'Item_Outlet_Sales']
