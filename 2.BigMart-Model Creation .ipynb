# %%
import pandas as pd
import numpy as np
# Out:
# D:\APPS\Anaconda\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df1=pd.read_csv('test.csv')

# %%
df1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
df2=pd.read_csv('train.csv')
df2
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#concat stack dataframe together,arg tell panda to ignore the index and continue for merge dataframe
merged_df = pd.concat([df1, df2], ignore_index=True)

# %%
merged_df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDW58       20.750          Low Fat         0.007565
# 1               FDW14        8.300              reg         0.038428
# 2               NCN55       14.600          Low Fat         0.099575
# 3               FDQ58        7.315          Low Fat         0.015388
# 4               FDY38          NaN          Regular         0.118599
# ...               ...          ...              ...              ...
# 14199           FDF22        6.865          Low Fat         0.056783
# 14200           FDS36        8.380          Regular         0.046982
# 14201           NCJ29       10.600          Low Fat         0.035186
# 14202           FDN46        7.210          Regular         0.145221
# 14203           DRG01       14.800          Low Fat         0.044878
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0             Snack Foods  107.8622            OUT049
# ...

# %% [markdown]
# #Getting Basic Info about the Dataset

# %%
merged_df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
merged_df.shape
# Out:
# (14204, 12)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11765 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
merged_df.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  11765.000000     14204.000000  14204.000000               14204.000000
# mean      12.792854         0.065953    141.004977                1997.830681
# std        4.652502         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        8.710000         0.027036     94.012000                1987.000000
# 50%       12.600000         0.054021    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       21.350000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# #2.Removing the null records

# %%
#checking the null records
merged_df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
#checking for null row
merged_df[merged_df['Item_Weight'].isnull()]
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4               FDY38          NaN          Regular         0.118599
# 7               FDC48          NaN          Low Fat         0.015782
# 12              NCC54          NaN          Low Fat         0.171079
# 18              NCM42          NaN          Low Fat         0.028184
# 23              NCL19          NaN          Low Fat         0.027447
# ...               ...          ...              ...              ...
# 14166           DRK37          NaN          Low Fat         0.043792
# 14168           DRG13          NaN          Low Fat         0.037006
# 14169           NCN14          NaN          Low Fat         0.091473
# 14171           FDU44          NaN          Regular         0.102296
# 14185           NCN18          NaN          Low Fat         0.124111
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 4                      Dairy  234.2300            OUT027
# ...

# %%
merged_df['Item_Weight'].isnull().sum()
# Out:
# 2439

# %%
merged_df['Item_Weight'].fillna(merged_df['Item_Weight'].mean(), inplace=True)
# Out:
# C:\Users\Rajesh\AppData\Local\Temp\ipykernel_8640\3851751522.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['Item_Weight'].fillna(merged_df['Item_Weight'].mean(), inplace=True)

# %%
merged_df[merged_df['Item_Weight'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
merged_df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    4655
# Small     3980
# High      1553
# Name: count, dtype: int64

# %%
#checking for null row ,for this dataset nothing is delete 
merged_df[merged_df['Outlet_Size'].isnull()]
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1               FDW14        8.300              reg         0.038428
# 2               NCN55       14.600          Low Fat         0.099575
# 3               FDQ58        7.315          Low Fat         0.015388
# 8               FDN33        6.305          Regular         0.123365
# 9               FDA36        5.985          Low Fat         0.005698
# ...               ...          ...              ...              ...
# 14183           NCH43        8.420          Low Fat         0.070712
# 14189           FDW31       11.350          Regular         0.043246
# 14190           FDG45        8.100          Low Fat         0.214306
# 14195           FDA01       15.000          Regular         0.054489
# 14200           FDS36        8.380          Regular         0.046982
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 1                      Dairy   87.3198            OUT017
# ...

# %%
#replace missing value with mode 
merged_df['Outlet_Size'].fillna(merged_df['Outlet_Size'].mode()[0], inplace=True)
# Out:
# C:\Users\Rajesh\AppData\Local\Temp\ipykernel_8640\665661847.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['Outlet_Size'].fillna(merged_df['Outlet_Size'].mode()[0], inplace=True)

# %%
merged_df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDW58    20.750000          Low Fat         0.007565
# 1               FDW14     8.300000              reg         0.038428
# 2               NCN55    14.600000          Low Fat         0.099575
# 3               FDQ58     7.315000          Low Fat         0.015388
# 4               FDY38    12.792854          Regular         0.118599
# ...               ...          ...              ...              ...
# 14199           FDF22     6.865000          Low Fat         0.056783
# 14200           FDS36     8.380000          Regular         0.046982
# 14201           NCJ29    10.600000          Low Fat         0.035186
# 14202           FDN46     7.210000          Regular         0.145221
# 14203           DRG01    14.800000          Low Fat         0.044878
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0             Snack Foods  107.8622            OUT049
# ...

# %%
merged_df['Item_Outlet_Sales'].fillna(merged_df['Item_Outlet_Sales'].mean(), inplace=True)
# Out:
# C:\Users\Rajesh\AppData\Local\Temp\ipykernel_8640\286207037.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['Item_Outlet_Sales'].fillna(merged_df['Item_Outlet_Sales'].mean(), inplace=True)

# %%
merged_df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
merged_df.info()
#checking for datatypes, confirm all correct
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                14204 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          14204 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
merged_df.drop(['Item_Identifier','Outlet_Identifier','Outlet_Establishment_Year'], axis=1, inplace=True)

# %%
merged_df
# Out:
#        Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0        20.750000          Low Fat         0.007565         Snack Foods
# 1         8.300000              reg         0.038428               Dairy
# 2        14.600000          Low Fat         0.099575              Others
# 3         7.315000          Low Fat         0.015388         Snack Foods
# 4        12.792854          Regular         0.118599               Dairy
# ...            ...              ...              ...                 ...
# 14199     6.865000          Low Fat         0.056783         Snack Foods
# 14200     8.380000          Regular         0.046982        Baking Goods
# 14201    10.600000          Low Fat         0.035186  Health and Hygiene
# 14202     7.210000          Regular         0.145221         Snack Foods
# 14203    14.800000          Low Fat         0.044878         Soft Drinks
#
#        Item_MRP Outlet_Size Outlet_Location_Type        Outlet_Type  \
# ...

# %%
merged_df[merged_df.duplicated]
#no duplicate rows
# Out:
# Empty DataFrame
# Columns: [Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
#convert all the categorical to numerical by using LabelEncoder
from sklearn.preprocessing import LabelEncoder
categorical_columns = ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

le = LabelEncoder()
for column in categorical_columns:
    merged_df[column] = le.fit_transform(merged_df[column])

# %%
merged_df
#from 12 coloum reduce to 9
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0        20.750000                 1         0.007565         13  107.8622
# 1         8.300000                 4         0.038428          4   87.3198
# 2        14.600000                 1         0.099575         11  241.7538
# 3         7.315000                 1         0.015388         13  155.0340
# 4        12.792854                 2         0.118599          4  234.2300
# ...            ...               ...              ...        ...       ...
# 14199     6.865000                 1         0.056783         13  214.5218
# 14200     8.380000                 2         0.046982          0  108.1570
# 14201    10.600000                 1         0.035186          8   85.1224
# 14202     7.210000                 2         0.145221         13  103.1332
# 14203    14.800000                 1         0.044878         14   75.4670
#
# ...

# %% [markdown]
# #Copying the clened data into new Dataframe

# %%
bigmart=merged_df.copy()
bigmart.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0    20.750000                 1         0.007565         13  107.8622
# 1     8.300000                 4         0.038428          4   87.3198
# 2    14.600000                 1         0.099575         11  241.7538
# 3     7.315000                 1         0.015388         13  155.0340
# 4    12.792854                 2         0.118599          4  234.2300
#
#    Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0            1                     0            1        2181.288914
# 1            1                     1            1        2181.288914
# 2            1                     2            0        2181.288914
# 3            1                     1            1        2181.288914
# 4            1                     2            3        2181.288914

# %%
#2 Model Creation

# %%
bigmart.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Item_Outlet_Sales'],
#       dtype='object')

# %%
#assign the input(indep) and output(dep) variable
indep=bigmart[['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type','Item_MRP', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',]]
dep=bigmart[['Item_Outlet_Sales']]

# %%
indep
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0        20.750000                 1         0.007565         13  107.8622
# 1         8.300000                 4         0.038428          4   87.3198
# 2        14.600000                 1         0.099575         11  241.7538
# 3         7.315000                 1         0.015388         13  155.0340
# 4        12.792854                 2         0.118599          4  234.2300
# ...            ...               ...              ...        ...       ...
# 14199     6.865000                 1         0.056783         13  214.5218
# 14200     8.380000                 2         0.046982          0  108.1570
# 14201    10.600000                 1         0.035186          8   85.1224
# 14202     7.210000                 2         0.145221         13  103.1332
# 14203    14.800000                 1         0.044878         14   75.4670
#
#        Outlet_Size  Outlet_Location_Type  Outlet_Type
# ...

# %%
dep
# Out:
#        Item_Outlet_Sales
# 0            2181.288914
# 1            2181.288914
# 2            2181.288914
# 3            2181.288914
# 4            2181.288914
# ...                  ...
# 14199        2778.383400
# 14200         549.285000
# 14201        1193.113600
# 14202        1845.597600
# 14203         765.670000
#
# [14204 rows x 1 columns]

# %%
#split the train and test data -import train_test_split function from skmodelselection module.this will split the data
#train/test set features/train/testset target variable,random ensure that same split obtain 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,Y_test=train_test_split(indep,dep,test_size=0.3,random_state=0)

# %%
X_train
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 7976     13.500000                 2         0.068149          4   58.6562
# 12641     5.655000                 1         0.085757          6  164.7500
# 7901     16.100000                 2         0.024988          6   97.3410
# 2009     17.000000                 1         0.135620          6  170.8106
# 13606     6.420000                 3         0.053426          4  178.7002
# ...            ...               ...              ...        ...       ...
# 13123     6.630000                 2         0.010984         13   55.4588
# 3264     12.792854                 2         0.083322          4  121.4756
# 9845      5.880000                 1         0.024926          9  149.9392
# 10799    12.792854                 2         0.024088          5  112.7176
# 2732      7.720000                 2         0.088365          6  118.7466
#
#        Outlet_Size  Outlet_Location_Type  Outlet_Type
# ...

# %%
X_train.shape
# Out:
# (9942, 8)

# %%
y_train.shape
# Out:
# (9942, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#y=mx+b y=(coef*PREDICT+intercept)

# %%
weight=regressor.coef_
weight
# Out:
# array([[  -5.46162176,   31.83721759, -824.36257806,   -2.67664651,
#            9.22358077, -173.20100966, -240.11802157,  584.26245291]])

# %%
weight=regressor.coef_
weight
# Out:
# array([[  -5.46162176,   31.83721759, -824.36257806,   -2.67664651,
#            9.22358077, -173.20100966, -240.11802157,  584.26245291]])

# %%
bais=regressor.intercept_
bais
# Out:
# array([744.8602959])

# %%
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([[2160.156943  ],
#        [2089.18441344],
#        [2848.2358153 ],
#        ...,
#        [3008.95907629],
#        [2274.31572292],
#        [2313.34483581]])

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,y_pred)

# %%
r_score
# Out:
# 0.31702211383995804

# %%
from sklearn.svm import SVR
regressor=SVR(kernel="poly",C=100)
regressor.fit(X_train,y_train)
# Out:
# D:\APPS\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=100, kernel='poly')

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,y_pred)

# %%
r_score
# Out:
# 0.006447177265839432

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=100,random_state=0)
regressor.fit(X_train,y_train)
# Out:
# D:\APPS\Anaconda\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=0)

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,y_pred)

# %%
r_score
# Out:
# 0.2961114853519575

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(criterion='squared_error', splitter='random', max_features='log2')
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_features='log2', splitter='random')

# %%
y_pred=regressor.predict(X_test)

# %%
r_score
# Out:
# 0.2961114853519575
